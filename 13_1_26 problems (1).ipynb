# %%
soil_nitrogen_level = int(input("Enter the soil nitrogen level (mg/kg): "))

# print("soil nitrogen level is 120mg/kg")

if soil_nitrogen_level < 100:
  print("Apply high nitrogen fertilizer (20000/bag)")
elif 100 <= soil_nitrogen_level <= 250:
  print("Apply medium nitrogen fertilizer (1000/bag)")
else:
  print("Apply low nitrogen fertilizer (10000/bag)")
# Out:
# Enter the soil nitrogen level (mg/kg): 120
# Apply medium nitrogen fertilizer (1000/bag)

# %%
crop=input("enter crop type(rice/wheat/sugarcane):")
moisture_level=float(input("enter moisture level(e.g., 35 for 35%)"))
temperature=input("enter current temperature condition(moderate/hot/cool):")
if crop =="rice" and moisture_level <40:
  temperatures = "moderate"
elif crop =="wheat" and moisture_level <30:
  temperatures = "moderate/cool"
# Out:
# enter crop type(rice/wheat/sugarcane):wheat
# enter moisture level(e.g., 35 for 35%)35
# enter current temperature condition(moderate/hot/cool):moderate

# %%
crop=input("enter crop type(rice/wheat/cotton):")
maturity_period=float(input("enter the maturity period(days)and harvest status:"))
if crop=="rice" and maturity_period >= 120 and maturity_period <= 150:
  status="ready to harvest"
elif crop=="wheat" and maturity_period >= 140 and maturity_period <= 180:
  status="ready to harvest"
elif crop=="cotton" and maturity_period >= 100 and maturity_period <= 120:
  status="ready to harvest"
else:
  status="not ready to harvest"
# Out:
# enter crop type(rice/wheat/cotton):wheat
# enter the maturity period(days)and harvest status:165

# %%
pest=int(input("no. of  pest"))
damage=int(input("crop damage percentage:"))
temp=int(input("enter the temperature"))
humidity=int(input("enter the humidity"))
print(f"pest per plant:{pest},damage:{damage}%,temp:{temp}C,humidity:{humidity}%")
if (pest<5)and (damage<10):
  print("severity level:low\n recommendation:no action required\n cost of intervention=0")
elif(pest<15) and (damage<25):
  print("severity level:medium\n recommendation:monitor daily\n cost of intervention=500/ha")
else:
      print("severity level:high\n recommendation :immediate action required\n cost of intervention=1000/ha")
# Out:
# no. of  pest12
# crop damage percentage:18
# enter the temperature28
# enter the humidity35
# pest per plant:12,damage:18%,temp:28C,humidity:35%
# severity level:medium
#  recommendation:monitor daily
#  cost of intervention=500/ha

# %%
rainfall =int(input("enter the rainfall"))
temperature=int(input("enter the temperature"))
wind_speed =int(input("enter the wind speed"))
print(f"rainfall:{rainfall},temperature:{temperature}c,windspeed:{wind_speed}km/h")
if rainfall>50:
  print("delay planting,do feild preparation")
elif temperature < 38:
  print("delay activities,focus on irrigation")
elif wind_speed>40:
  print("go ahead with planned activities")
# Out:
# enter the rainfall60
# enter the temperature33
# enter the wind speed25
# rainfall:60,temperature:33c,windspeed:25km/h
# delay planting,do feild preparation
